# %%
from datetime import datetime
from meteostat import Point, Daily

# %%
# Set time period
start = datetime(2015, 1, 1)
end = datetime(2024, 6, 30)

# %%
# Create Point for Maracanã, RJ - BR
dados = Point(-22.913645, -43.225313)

# %%
# Get daily data (01/2015 - 06/2024)
data = Daily(dados, start, end)
data = data.fetch()
data.head(20)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  pres  tsun
# time
# 2015-01-01  29.8  24.0  38.0   NaN   NaN   47.0  10.0   NaN   NaN   NaN
# 2015-01-02  30.8  26.0  39.0   NaN   NaN   28.0   8.3   NaN   NaN   NaN
# 2015-01-03  29.4  27.0  33.0   NaN   NaN  135.0  17.2   NaN   NaN   NaN
# 2015-01-04  27.5  24.0  33.0   NaN   NaN   62.0  10.0   NaN   NaN   NaN
# 2015-01-05  25.9  22.0  31.0   NaN   NaN  345.0   9.7   NaN   NaN   NaN
# 2015-01-06  26.1  23.0  31.0   NaN   NaN   53.0   9.3   NaN   NaN   NaN
# 2015-01-07  28.8  24.0  35.0   NaN   NaN   93.0   9.9   NaN   NaN   NaN
# 2015-01-08  29.6  24.0  36.0   NaN   NaN   93.0  11.6   NaN   NaN   NaN
# 2015-01-09  31.1  25.0  38.0   NaN   NaN   78.0   8.8   NaN   NaN   NaN
# 2015-01-10  31.6  25.0  39.0   NaN   NaN  103.0   9.1   NaN   NaN   NaN
# 2015-01-11  30.4  25.0  37.0   NaN   NaN  185.0  12.4   NaN   NaN   NaN
# 2015-01-12  31.6  26.0  39.0   NaN   NaN  212.0  11.1   NaN   NaN   NaN
# ...

# %%
#data.to_excel('D:\Mestrado\Defesa\Clima - Bairros RJ\Maracana\Maracana-2015-2024_Diario.xlsx')
